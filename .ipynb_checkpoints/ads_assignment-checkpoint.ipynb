# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
def cleanse(df):
    """
        This function takes a DataFrame, 
        cleans or prepares it and returns it 
        for further analysis
    """
    
    # Removing duplicate data
    df = df.drop_duplicates()
    
    # cleanse(slr)
    for col in df.columns:
        if df[col].isna().all():
            df.dropna()
    
    return df

# %%
slr = pd.read_csv("salaries.csv", index_col = 0)

# slr = pd.reIndex(inplace = True)

slr.reset_index(drop = False, inplace = True)

slr = cleanse(slr)

slr_usd = slr['salary_in_usd']

slr_usd.corr(slr.salary, method = "kendall")
# Out:
# 0.9208317919034207

# %%
slr.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  5129.000000  5.129000e+03    5129.000000   5129.000000
# mean   2022.655098  1.884957e+05  144969.799571     44.531098
# std       0.630861  5.951330e+05   67837.508198     48.634027
# min    2020.000000  1.400000e+04   15000.000000      0.000000
# 25%    2022.000000  9.910000e+04   95000.000000      0.000000
# 50%    2023.000000  1.407000e+05  139500.000000      0.000000
# 75%    2023.000000  1.900000e+05  185700.000000    100.000000
# max    2023.000000  3.040000e+07  615201.000000    100.000000

# %%
slr
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 4          2023               SE              FT
# 5          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...
